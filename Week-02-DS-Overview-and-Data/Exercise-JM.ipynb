# %% [markdown]
# # Fall 2024 Data Science Track: Week 2 - Data Cleaning Exercise

# %% [markdown]
# ## Packages, Packages, Packages!
#
# Import *all* the things here! You need the standard stuff: `pandas` and `numpy`.
#
# If you got more stuff you want to use, add them here too. 🙂

# %%
# Import here.
import pandas as pd
import numpy as np

# %% [markdown]
# ## Introduction
#
# With the packages out of the way, now you will be working with the following data sets:
#
# * `food_coded.csv`: [Food choices](https://www.kaggle.com/datasets/borapajo/food-choices?select=food_coded.csv) from Kaggle
# * `Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv`: [Ask A Manager Salary Survey 2021 (Responses)](https://docs.google.com/spreadsheets/d/1IPS5dBSGtwYVbjsfbaMCYIWnOuRmJcbequohNxCyGVw/view?&gid=1625408792) as *Tab Separated Values (.tsv)* from Google Docs
#
# Each one poses different challenges. But you’ll―of course―overcome them with what you learned in class! 😉

# %% [markdown]
# ## Food Choices Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Food choices data set into a variable (e.g., df_food).

food_data_set_path = 'data/food_coded.csv'

df_food = pd.read_csv(food_data_set_path)

# %% [markdown]
# ### Explore the Data

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. (lol kidding)
print(f'I loaded {len(df_food)} entries.')
# Out:
# I loaded 125 entries.

# %% [markdown]
# What are the columns and their types in this data set?

# %%
# Show the column names and their types.

df_food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           123 non-null    object
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  106 non-null    float64
#  5   calories_scone                124 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  124 non-null    object
#  8   comfort_food_reasons          123 non-null    object
#  9   comfort_food_reasons_coded    106 non-null    float64
#  10  cook                          122 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
# ...

# %% [markdown]
# ### Clean the Data
#
# Perhaps we’d like to know more another day, but the team is really interested in just the relationship between calories (`calories_day`) and weight. …and maybe gender.

# %% [markdown]
# Can you remove the other columns?

# %%
# Remove ‘em.

df_food = df_food[["calories_day", "weight", "Gender"]]

#Checking to ensure the change took place properly
df_food
# Out:
#      calories_day                    weight  Gender
# 0             NaN                       187       2
# 1             3.0                       155       1
# 2             4.0  I'm not answering this.        1
# 3             3.0             Not sure, 240       1
# 4             2.0                       190       1
# ..            ...                       ...     ...
# 120           4.0                       156       1
# 121           2.0                       180       1
# 122           NaN                       120       1
# 123           4.0                       135       2
# 124           NaN                       135       1
#
# [125 rows x 3 columns]

# %% [markdown]
# What about `NaN`s? How many are there?

# %%
# Count ‘em.

nanSum = 0
for nanCt in df_food.isnull().sum():
    nanSum += nanCt

print(f'THere are a total of {nanSum} NaNs in the data.')
# Out:
# THere are a total of 21 NaNs in the data.

# %% [markdown]
# We gotta remove those `NaN`s―the entire row.

# %%
# Drop ‘em.

df_food = df_food.dropna()

#Checking to ensure the change took place
df_food
# Out:
#      calories_day                    weight  Gender
# 1             3.0                       155       1
# 2             4.0  I'm not answering this.        1
# 3             3.0             Not sure, 240       1
# 4             2.0                       190       1
# 5             3.0                       190       1
# ..            ...                       ...     ...
# 118           3.0                       140       1
# 119           3.0                       185       2
# 120           4.0                       156       1
# 121           2.0                       180       1
# 123           4.0                       135       2
#
# [104 rows x 3 columns]

# %% [markdown]
# But what about the weird non-numeric values in the column obviously meant for numeric data?
#
# Notice the data type of that column from when you got the types of all the columns?
#
# If only we could convert the column to a numeric type and drop the rows with invalid values. 🤔

# %%
# Fix that.

#Converting to numeric data
df_food['weight'] = pd.to_numeric(df_food['weight'], errors='coerce')

#Dropping NaNs
df_food = df_food.dropna()

#Checking if the change was made
df_food
# Out:
# C:\Users\swift\AppData\Local\Temp\ipykernel_24164\2272147878.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_food['weight'] = pd.to_numeric(df_food['weight'], errors='coerce')
#      calories_day  weight  Gender
# 1             3.0   155.0       1
# 4             2.0   190.0       1
# 5             3.0   190.0       1
# 6             3.0   180.0       2
# 7             3.0   137.0       1
# ..            ...     ...     ...
# 118           3.0   140.0       1
# 119           3.0   185.0       2
# 120           4.0   156.0       1
# 121           2.0   180.0       1
# 123           4.0   135.0       2
#
# [101 rows x 3 columns]

# %% [markdown]
# Now this data seems reasonably clean for our purposes! 😁
#
# Let’s save it somewhere to be shipped off to another teammate. 💾

# %%
# Savey save!

df_food.to_csv('data/food_cleaned.csv', index=False)

# %% [markdown]
# ## Ask a Manager Salary Survey 2021 (Responses) Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Ask A Manager Salary Survey 2021 (Responses) data set into a variable (e.g., df_salary).

df_salary = pd.read_csv('data/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv', sep = "	")

# %% [markdown]
# Was that hard? 🙃

# %% [markdown]
# #### rename the file to something that is better for all systems.
# * No spaces in filename (can use '_')
# * all lower case

# %% [markdown]
# ### Explore
#
# You know the drill.

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. I’m dead serious.

print(f'I loaded {len(df_salary)} entries.')
# Out:
# I loaded 28062 entries.

# %% [markdown]
# What are the columns and their types?

# %%
# Show the column names and their types.

df_salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28062 entries, 0 to 28061
# Data columns (total 18 columns):
#  #   Column                                                                                                                                                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                --------------  -----
#  0   Timestamp                                                                                                                                                                                                                             28062 non-null  object
# ...

# %% [markdown]
# Oh… Ugh! Give these columns easier names to work with first. 🙄

# %%
# Rename ‘em.
# Non-binding suggestions: timestamp, age, industry, title, title_context, salary, additional_compensation, currency, other_currency, salary_context, country, state, city, total_yoe, field_yoe, highest_education_completed	gender, race

df_salary = df_salary.rename(columns={
    'Timestamp': 'timestamp',
    'How old are you?': 'age',
    'What industry do you work in?': 'industry',
    'Job title': 'title',
    'If your job title needs additional context, please clarify here:': 'title_context',
    "What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)": 'salary',
    "How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.": 'additional_compensation',
    "Please indicate the currency": 'currency',
    '''If "Other," please indicate the currency here: ''': 'other_currency',
    'If your income needs additional context, please provide it here:':'salary_context',
    'What country do you work in?':'country',
    "If you're in the U.S., what state do you work in?":'state',
    "What city do you work in?":"city",
    'How many years of professional work experience do you have overall?':'total_yoe',
    "How many years of professional work experience do you have in your field?":"field_yoe",
    "What is your highest level of education completed?":'highest_education_completed',
    'What is your gender?':'gender',
    'What is your race? (Choose all that apply.)':'race'})

#Checking if the operation worked
df_salary.columns
# Out:
# Index(['timestamp', 'age', 'industry', 'title', 'title_context', 'salary',
#        'additional_compensation', 'currency', 'other_currency',
#        'salary_context', 'country', 'state', 'city', 'total_yoe', 'field_yoe',
#        'highest_education_completed', 'gender', 'race'],
#       dtype='object')

# %% [markdown]
# It’s a lot, and that should not have been easy. 😏

# %% [markdown]
# You’re going to have a gander at the computing/tech subset first because thats *your* industry. But first, what value corresponds to that `industry`?

# %%
# List the unique industries and a count of their instances.
df_salary["industry"].value_counts()
# Out:
# industry
# Computing or Tech                          4699
# Education (Higher Education)               2464
# Nonprofits                                 2419
# Health care                                1896
# Government and Public Administration       1889
#                                            ...
# Gaming (Gambling)                             1
# Regulatory Affairs- nutraceuticals            1
# Manufacturing : corporate admin support       1
# Real Estate Investment Support                1
# Wine & Spirits                                1
# Name: count, Length: 1219, dtype: int64

# %% [markdown]
# That value among the top 5 is what you’re looking for innit? Filter out all the rows not in that industry and save it into a new dataframe.

# %%
# Filtery filter. (Save it to a new variable, df_salary_tech.)

#Using a boolean mask
df_salary_tech = df_salary[df_salary["industry"] == "Computing or Tech"]

# %% [markdown]
# Do a sanity check to make sure that the only values you kept are the one you are filtered for.

# %%
# Sanity Check 

df_salary_tech
# Out:
#                 timestamp    age           industry  \
# 1      4/27/2021 11:02:22  25-34  Computing or Tech
# 8      4/27/2021 11:03:01  45-54  Computing or Tech
# 43     4/27/2021 11:04:04  25-34  Computing or Tech
# 44     4/27/2021 11:04:04  25-34  Computing or Tech
# 46     4/27/2021 11:04:07  35-44  Computing or Tech
# ...                   ...    ...                ...
# 28050   7/1/2024 13:38:46  25-34  Computing or Tech
# 28051   7/1/2024 20:05:58  25-34  Computing or Tech
# 28052   7/3/2024 14:02:01  25-34  Computing or Tech
# 28058  7/23/2024 17:51:03  25-34  Computing or Tech
# 28060  7/26/2024 11:20:45  18-24  Computing or Tech
#
#                                               title  \
# 1          Change & Internal Communications Manager
# 8                                   Systems Analyst
# 43                      Principal Software Engineer
# 44                             Intelligence Analyst
# 46                                 Mobile developer
# ...

# %% [markdown]
# We are very interested in salary figures. But how many dollars 💵 is a euro 💶 or a pound 💷? That sounds like a problem for another day. 🫠
#
# For now, let’s just look at U.S. dollars (`'USD'`).

# %%
# Filtery filter for just the jobs that pay in USD!

#Using a boolean mask
df_salary_tech = df_salary_tech[df_salary_tech["currency"] == "USD"]

df_salary_tech
# Out:
#                 timestamp    age           industry  \
# 8      4/27/2021 11:03:01  45-54  Computing or Tech
# 43     4/27/2021 11:04:04  25-34  Computing or Tech
# 44     4/27/2021 11:04:04  25-34  Computing or Tech
# 46     4/27/2021 11:04:07  35-44  Computing or Tech
# 47     4/27/2021 11:04:09  35-44  Computing or Tech
# ...                   ...    ...                ...
# 28044   6/3/2024 16:15:43  18-24  Computing or Tech
# 28051   7/1/2024 20:05:58  25-34  Computing or Tech
# 28052   7/3/2024 14:02:01  25-34  Computing or Tech
# 28058  7/23/2024 17:51:03  25-34  Computing or Tech
# 28060  7/26/2024 11:20:45  18-24  Computing or Tech
#
#                                         title                 title_context  \
# 8                             Systems Analyst  Data developer/ETL Developer
# 43                Principal Software Engineer                           NaN
# 44                       Intelligence Analyst                           NaN
# ...

# %% [markdown]
# What we really want know is how each U.S. city pays in tech. What value in `country` represents the United States of America?

# %%
# We did filter for USD, so if we do a count of each unique country in descending count order, the relevant value(s) should show up at the top.

toPrint = df_salary_tech["country"].value_counts(ascending=False)

#Printing just the values for the United States
print(toPrint[0:5])
# Out:
# country
# United States               1576
# USA                         1222
# US                           412
# U.S.                         108
# United States of America      90
# Name: count, dtype: int64

# %% [markdown]
# ### Clean the Data
#
# Well, we can’t get our answers with what we currently have, so you’ll have to make some changes.

# %% [markdown]
# Let’s not worry about anything below the first 5 values for now. Convert the top 5 to a single canonical value―say, `'US'`, which is nice and short.

# %%
# Replace them all with 'US'.

df_salary_tech.replace(["United States", "USA", "US", "U.S.", "United States of America"], "US", inplace=True)

#Checking if the operation was done correctly
df_salary_tech
# Out:
# C:\Users\swift\AppData\Local\Temp\ipykernel_24164\4043086780.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salary_tech.replace(["United States", "USA", "US", "U.S.", "United States of America"], "US", inplace=True)
#                 timestamp    age           industry  \
# 8      4/27/2021 11:03:01  45-54  Computing or Tech
# 43     4/27/2021 11:04:04  25-34  Computing or Tech
# 44     4/27/2021 11:04:04  25-34  Computing or Tech
# 46     4/27/2021 11:04:07  35-44  Computing or Tech
# 47     4/27/2021 11:04:09  35-44  Computing or Tech
# ...                   ...    ...                ...
# 28044   6/3/2024 16:15:43  18-24  Computing or Tech
# 28051   7/1/2024 20:05:58  25-34  Computing or Tech
# 28052   7/3/2024 14:02:01  25-34  Computing or Tech
# ...

# %% [markdown]
# Have a look at the count of each unique country again now.

# %%
# Count again.

df_salary_tech["country"].value_counts()
# Out:
# country
# US                3408
# United States       68
# Usa                 59
# USA                 56
# usa                 28
#                   ...
# Mexico               1
# United Stateds       1
# ISA                  1
# singapore            1
# Burma                1
# Name: count, Length: 72, dtype: int64

# %% [markdown]
# Did you notice anything interesting?

# %% [markdown]
# Jagmeet: Yes, it seems the 'United States' value wasn't fully replaced.

# %%
# BONUS CREDIT: resolve [most of] those anomalous cases too without exhaustively taking every variant literally into account.

#Iterate through the various country values in the dataframe - the items method returns tuples
for country in df_salary_tech["country"].value_counts().items():
    #If the first element of the tuple (the country name) has an U and S we can conclusively say it is most likely a variation of USA
    #Convert to lowercase to account for case mismatch
    if "u" in country[0].lower() and "s" in country[0].lower():
        #Replace the anamolous value
        df_salary_tech.replace(country, "US", inplace=True)
# Out:
# C:\Users\swift\AppData\Local\Temp\ipykernel_24164\1057766093.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salary_tech.replace(country, "US", inplace=True)

# %%
# BONUS CREDIT: if you’ve resolved it, let’s see how well you did by counting the number of instances of each unique value.

df_salary_tech["country"].value_counts()
# Out:
# country
# US                      3725
# Israel                     5
# Canada                     4
# Poland                     2
# New Zealand                2
# United Kingdom             2
# Brazil                     2
# India                      2
# Spain                      2
# France                     2
# denmark                    1
# Colombia                   1
# Thailand                   1
# Netherlands                1
# Jamaica                    1
# Ghana                      1
# Denmark                    1
# Nigeria                    1
# Japan                      1
# Romania                    1
# San Francisco              1
# China                      1
# ss                         1
# Nigeria                    1
# singapore                  1
# Pakistan                   1
# America                    1
# ISA                        1
# Canada                     1
# Mexico                     1
# Uruguay                    1
# ...

# %% [markdown]
# It’s looking good so far. Let’s find out the minimum, mean, and maximum (in that order) salary by state, sorted by the mean in descending order.

# %%
# Find the minimum, mean, and maximum salary in USD by U.S. state.

df_salary_tech.groupby("state")['salary'].agg(["min", "mean", "max"]).sort_values(by="mean", ascending=False)
#Salary does not have numeric values so this produces an error
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File c:\Users\swift\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File c:\Users\swift\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# ...

# %% [markdown]
# Well, pooh! We forgot that `salary` isn’t numeric. Something wrong must be fixed.

# %%
# Fix it.

df_salary_tech['salary'] = pd.to_numeric(df_salary_tech['salary'], errors='coerce')

# %% [markdown]
# Let’s try that again.

# %%
# Try it again. Yeah!

df_salary_tech.groupby("state")['salary'].agg(["min", "mean", "max"]).sort_values(by="mean", ascending=False)
# Out:
#                                   min      mean        max
# state
# Michigan, Texas, Washington  340000.0  340000.0   340000.0
# Florida                       28800.0  210711.0  2600000.0
# California, Oregon           200000.0  200000.0   200000.0
# California, Colorado         176000.0  176000.0   176000.0
# Delaware                     169000.0  169000.0   169000.0
# ...                               ...       ...        ...
# Mississippi                       NaN       NaN        NaN
# New York, Texas                   NaN       NaN        NaN
# North Dakota                      NaN       NaN        NaN
# South Dakota                      NaN       NaN        NaN
# Utah, Vermont                     NaN       NaN        NaN
#
# [66 rows x 3 columns]

# %% [markdown]
# That did the trick! Now let’s narrow this to data 2021 and 2022 just because (lel). *(Hint: that timestamp column may not be a temporal type right now.)*

# %%
# Filter the data to within 2021, 2022, or 2023, saving the DataFrame to a new variable, and generate the summary again.

df_salary_tech['timestamp'] = pd.to_datetime(df_salary_tech['timestamp'], errors = 'coerce')

years = [2021, 2022]

df_salary_tech_adjusted = df_salary_tech[df_salary_tech["timestamp"].dt.year.isin(years)]

df_salary_tech_adjusted
# Out:
#       index           timestamp    age           industry  \
# 0         8 2021-04-27 11:03:01  45-54  Computing or Tech
# 1        43 2021-04-27 11:04:04  25-34  Computing or Tech
# 2        44 2021-04-27 11:04:04  25-34  Computing or Tech
# 3        46 2021-04-27 11:04:07  35-44  Computing or Tech
# 4        47 2021-04-27 11:04:09  35-44  Computing or Tech
# ...     ...                 ...    ...                ...
# 3745  27887 2022-10-19 18:19:22  35-44  Computing or Tech
# 3746  27888 2022-10-21 19:59:05  25-34  Computing or Tech
# 3747  27892 2022-11-03 17:18:54  35-44  Computing or Tech
# 3748  27907 2022-11-30 16:49:40  25-34  Computing or Tech
# 3749  27915 2022-12-13 18:21:14  25-34  Computing or Tech
#
#                                 title                 title_context    salary  \
# 0                     Systems Analyst  Data developer/ETL Developer       NaN
# 1         Principal Software Engineer                           NaN       NaN
# ...

# %% [markdown]
# ## Bonus
#
# Clearly, we do not have enough data to produce useful figures for the level of specificity you’ve now reached. What do you notice about Delaware and West Virginia?
#
# Let’s back out a bit and return to `df_salary` (which was the loaded data with renamed columns but *sans* filtering).

# %% [markdown]
# ### Bonus #0
#
# Apply the same steps as before to `df_salary`, but do not filter for any specific industry. Do perform the other data cleaning stuff, and get to a point where you can generate the minimum, mean, and maximum by state.

# %%
#I'm assuming this means the minimum, mean, and maximum salary

#Dropping NaNs
df_salary.dropna(subset=["salary"], inplace=True)

#Converting salary to a numeric value
df_salary['salary'] = pd.to_numeric(df_salary['salary'], errors='coerce')

df_salary.groupby("state")["salary"].agg(["min", "mean", "max"])
# Out:
#                                 min          mean        max
# state
# Alabama                         0.0  6.552491e+04   350000.0
# Alabama, Alaska, Arizona       15.0  1.500000e+01       15.0
# Alabama, California         29120.0  2.912000e+04    29120.0
# Alabama, Oregon             50000.0  5.000000e+04    50000.0
# Alabama, South Carolina   5000000.0  5.000000e+06  5000000.0
# ...                             ...           ...        ...
# Virginia                       57.0  9.621905e+04  1300000.0
# Washington                     72.0  9.803290e+04   300000.0
# West Virginia                   0.0  5.275438e+04   120000.0
# Wisconsin                       1.0  8.300063e+04   920000.0
# Wyoming                     42500.0  5.990633e+04    98000.0
#
# [84 rows x 3 columns]

# %% [markdown]
# ### Bonus #1
#
# This time, format the table output nicely (*$12,345.00*) without modifying the values in the `DataFrame`. That is, `df_salary` should be identical before versus after running your code.
#
# (*Hint: if you run into an error about `jinja2` perhaps you need to `pip install` something.*)

# %%
#The .style.format method allows for quick formatting of a dataframe
#The downside is this only supported by certain environments such as jupyter notebooks
df_salary.groupby("state")["salary"].agg(["min", "mean", "max"]).style.format("${:,.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_a0ae7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0ae7_level0_col0" class="col_heading level0 col0" >min</th>
#       <th id="T_a0ae7_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_a0ae7_level0_col2" class="col_heading level0 col2" >max</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >state</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0ae7_level0_row0" class="row_heading level0 row0" >Alabama</th>
#       <td id="T_a0ae7_row0_col0" class="data row0 col0" >$0.00</td>
#       <td id="T_a0ae7_row0_col1" class="data row0 col1" >$65,524.91</td>
#       <td id="T_a0ae7_row0_col2" class="data row0 col2" >$350,000.00</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ### Bonus #2
#
# Filter out the non-single-states (e.g., `'California, Colorado'`) in the most elegant way possible (i.e., *not* by blacklisting all the bad values).

# %%
#I'm not sure if this counts as blacklisting the values but the only other way I could think of was defining a function which would essentially
#do the same thing but take up more space

df_salary[~df_salary["state"].str.contains(",", na=False)]
# Out:
#                 timestamp    age                       industry  \
# 97     4/27/2021 11:05:08  55-64       Environmental regulation
# 166    4/27/2021 11:06:07  25-34                    Health care
# 895    4/27/2021 11:16:37  45-54  Education (Primary/Secondary)
# 968    4/27/2021 11:17:54  25-34                Media & Digital
# 1607   4/27/2021 11:28:23  25-34        Agriculture or Forestry
# ...                   ...    ...                            ...
# 28057  7/12/2024 22:52:01  35-44                    Health care
# 28058  7/23/2024 17:51:03  25-34              Computing or Tech
# 28059  7/24/2024 12:22:58  18-24  Accounting, Banking & Finance
# 28060  7/26/2024 11:20:45  18-24              Computing or Tech
# 28061   8/20/2024 1:06:13  25-34                    Health care
#
#                            title title_context     salary  \
# 97        Quality Assurance Lead           NaN       58.0
# 166       occupational therapist           NaN       35.0
# ...

# %% [markdown]
# ### Bonus #3
#
# Show the quantiles instead of just minimum, mean, and maximum―say 0%, 5%, 25%, 50%, 75%, 95%, and 100%. Outliers may be deceiving.
#
# Sort by whatever interests you―like say the *50th* percentile.
#
# And throw in a count by state too. It would be interesting to know how many data points contribute to the figures for each state. (*Hint: your nice formatting from Bonus #1 might not work this time around.* 😜)

# %%
#The describe method will show BOTH count and percentiles, I sorted by the 50th percentile column
df_salary.groupby("state")["salary"].describe().sort_values(by="50%", ascending=True)
# Out:
#                                                     count          mean  \
# state
# Colorado, Delaware, New Jersey, West Virginia, ...    1.0  5.000000e+00
# Alabama, Alaska, Arizona                              1.0  1.500000e+01
# Maryland, New York                                    1.0  1.400000e+04
# Alabama, California                                   1.0  2.912000e+04
# Delaware, Pennsylvania                                1.0  3.500000e+04
# ...                                                   ...           ...
# New Jersey, New York                                  3.0  1.386667e+05
# California, Colorado                                  1.0  1.760000e+05
# California, Oregon                                    1.0  2.000000e+05
# Michigan, Texas, Washington                           1.0  3.400000e+05
# Alabama, South Carolina                               1.0  5.000000e+06
#
#                                                             std        min  \
# state
# ...
